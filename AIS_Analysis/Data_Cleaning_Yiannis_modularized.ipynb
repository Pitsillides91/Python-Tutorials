# %%
import pandas as pd
import numpy as np
import geopandas as gpd
from shapely.geometry import Point
from scipy.spatial import cKDTree
from geopy.distance import geodesic
from helper_utils import load_raw_data, load_port_info, load_port_polygons
from data_cleaning import remove_NA, remove_invalid_lat_and_lon, remove_invalid_speed


def load_and_clean_data(parquet_file_path):
    """Load and clean AIS raw data."""
    ais_raw_data = load_raw_data(parquet_file_path)

    # Remove invalid data and duplicates
    ais_raw_data = remove_NA(ais_raw_data)
    ais_raw_data = remove_invalid_lat_and_lon(ais_raw_data)
    ais_raw_data = remove_invalid_speed(ais_raw_data)
    ais_raw_data = ais_raw_data.drop_duplicates()
    return ais_raw_data


def investigate_data(data, name="Data"):
    """Print unique values and null counts for a dataset."""
    print(f"Investigating {name}:")
    for column in data:
        unique_vals = np.unique(data[column])
        nr_values = len(unique_vals)
        if nr_values < 12:
            print(f'The number of values for feature {column}: {nr_values} -- {unique_vals}')
        else:
            print(f'The number of values for feature {column}: {nr_values}')
    print("\nNull value counts:")
    print(data.isnull().sum())


def create_proximity_columns(ais_raw_data, port_info):
    """Create proximity columns and assign nearest port information."""
    # Prepare data
    vessel_coords = ais_raw_data[['latitude', 'longitude']].to_numpy()
    port_coords = port_info[['Latitude', 'Longitude']].to_numpy()
    port_names = port_info['Main Port Name'].to_numpy()

    # Build KD-Tree for efficient nearest neighbor search
    port_tree = cKDTree(port_coords)
    distances, indices = port_tree.query(vessel_coords, k=1)

    # Add proximity information
    ais_raw_data['Distance to Nearest Port'] = distances
    ais_raw_data['Proximity Port Name'] = [port_names[i] for i in indices]
    ais_raw_data['Port Latitude'] = [port_coords[i][0] for i in indices]
    ais_raw_data['Port Longitude'] = [port_coords[i][1] for i in indices]

    # Add proximity columns with thresholds
    for dist, label in zip([1, 3, 5, 10], ['1 km', '3 km', '5 km', '10 km']):
        ais_raw_data[f'Less than {label} from port'] = np.where(ais_raw_data['Distance to Nearest Port'] <= dist, "Yes", "No")

    # Remove port data for vessels not near any port
    ais_raw_data.loc[
        (ais_raw_data['Less than 1 km from port'] == "No") &
        (ais_raw_data['Less than 3 km from port'] == "No") &
        (ais_raw_data['Less than 5 km from port'] == "No") &
        (ais_raw_data['Less than 10 km from port'] == "No"),
        ['Proximity Port Name', 'Port Latitude', 'Port Longitude']
    ] = ["No", np.nan, np.nan]

    return ais_raw_data


def process_with_polygons(ais_raw_data, polygons, chunk_size=10000):
    """Check vessel locations against port polygons using spatial joins."""
    # Ensure correct CRS
    polygons = polygons.set_geometry("polygon").to_crs("EPSG:4326")

    def process_chunk(chunk):
        chunk['geometry'] = gpd.points_from_xy(chunk['longitude'], chunk['latitude'])
        vessels_gdf = gpd.GeoDataFrame(chunk, geometry='geometry', crs="EPSG:4326")

        # Perform spatial join
        joined = gpd.sjoin(vessels_gdf, polygons, how='left', predicate='within')
        joined['Parked in Port'] = joined['index_right'].notnull()
        joined['Port Name'] = joined['port_name'].where(joined['Parked in Port'], "No")
        return joined.drop(columns=['geometry', 'index_right'])

    # Process in chunks
    results = []
    for i in range(0, len(ais_raw_data), chunk_size):
        chunk = ais_raw_data.iloc[i:i + chunk_size]
        results.append(process_chunk(chunk))

    # Combine results
    return pd.concat(results, ignore_index=True)


def main():
    # File paths
    parquet_file_path = "data/raw_data/raw_data.parquet"

    # Load and clean AIS data
    ais_raw_data = load_and_clean_data(parquet_file_path)

    # Load port data and polygons
    port_info = pd.DataFrame(load_port_info()).drop_duplicates()
    polygons = load_port_polygons().drop_duplicates()

    # Investigate data
    investigate_data(ais_raw_data, "AIS Raw Data")
    investigate_data(port_info, "Port Information")

    # Create proximity columns
    ais_raw_data = create_proximity_columns(ais_raw_data, port_info)

    # Process spatial join with polygons
    final_results = process_with_polygons(ais_raw_data, polygons)

    # Save final results
    final_results.to_csv('vessels_with_parked_status.csv', index=False)
    print("Processing completed successfully!")


if __name__ == "__main__":
    main()
# Out:
# **************
# *** STEP 1 ***
# Dropping rows with missing values...
# Rows after droping NA:  21570312
# **************
#
# **************
# *** STEP 2 ***
# Removing rows with invalid latitudes and longitudes...
# Rows after droping invalid rows with latitudes and longitudes:  21570312
# **************
#
# **************
# *** STEP 3 ***
# Removing rows with invalid speed...
# Rows after droping invalid speed:  20277918
# **************
#
# Investigating AIS Raw Data:
# The number of values for feature latitude: 14534154
# The number of values for feature longitude: 16305103
# The number of values for feature speed: 473
# The number of values for feature course: 361
# The number of values for feature time_of_position: 4598662
# The number of values for feature anonymized_mmsi: 121
#
# Null value counts:
# latitude            0
# longitude           0
# speed               0
# course              0
# time_of_position    0
# anonymized_mmsi     0
# dtype: int64
# Investigating Port Information:
# The number of values for feature ﻿OID_: 3711
# The number of values for feature World Port Index Number: 3710
# The number of values for feature Region Name: 345
# The number of values for feature Main Port Name: 3711
# The number of values for feature Alternate Port Name: 840
# The number of values for feature UN/LOCODE: 3242
# The number of values for feature Country Code: 194
# The number of values for feature World Water Body: 137
# The number of values for feature IHO S-130 Sea Area: 1 -- [' ']
# The number of values for feature Sailing Direction or Publication: 50
# The number of values for feature Publication Link: 50
# The number of values for feature Standard Nautical Chart: 1716
# The number of values for feature IHO S-57 Electronic Navigational Chart: 1 -- [' ']
# The number of values for feature IHO S-101 Electronic Navigational Chart: 1 -- [' ']
# The number of values for feature Digital Nautical Chart: 2121
# The number of values for feature Tidal Range (m): 71
# The number of values for feature Entrance Width (m): 60
# The number of values for feature Channel Depth (m): 115
# The number of values for feature Anchorage Depth (m): 94
# The number of values for feature Cargo Pier Depth (m): 101
# The number of values for feature Oil Terminal Depth (m): 129
# The number of values for feature Liquified Natural Gas Terminal Depth (m): 12
# The number of values for feature Maximum Vessel Length (m): 283
# The number of values for feature Maximum Vessel Beam (m): 136
# The number of values for feature Maximum Vessel Draft (m): 164
# The number of values for feature Offshore Maximum Vessel Length (m): 67
# The number of values for feature Offshore Maximum Vessel Beam (m): 10 -- ['0.0' '32.3' '33.0' '42.0' '44.0' '50.0' '55.0' '58.0' '60.0' '70.0']
# The number of values for feature Offshore Maximum Vessel Draft (m): 71
# The number of values for feature Harbor Size: 5 -- [' ' 'Large' 'Medium' 'Small' 'Very Small']
# The number of values for feature Harbor Type: 10 -- [' ' 'Canal or Lake' 'Coastal (Breakwater)' 'Coastal (Natural)'
#  'Coastal (Tide Gates)' 'Open Roadstead' 'River (Basins)'
#  'River (Natural)' 'River (Tide Gates)' 'Typhoon Harbor']
# The number of values for feature Harbor Use: 5 -- ['Cargo' 'Ferry' 'Fishing' 'Military' 'Unknown']
# The number of values for feature Shelter Afforded: 7 -- [' ' 'Excellent' 'Fair' 'Good' 'None' 'Poor' 'Unknown']
# The number of values for feature Entrance Restriction - Tide: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Entrance Restriction - Heavy Swell: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Entrance Restriction - Ice: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Entrance Restriction - Other: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Overhead Limits: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Underkeel Clearance Management System: 2 -- ['None' 'Unknown']
# The number of values for feature Good Holding Ground: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Turning Area: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Port Security: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Estimated Time of Arrival Message: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Quarantine - Pratique: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Quarantine - Sanitation: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Quarantine - Other: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Traffic Separation Scheme: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Vessel Traffic Service: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature First Port of Entry: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature US Representative: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Pilotage - Compulsory: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Pilotage - Available: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Pilotage - Local Assistance: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Pilotage - Advisable: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Tugs - Salvage: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Tugs - Assistance: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Communications - Telephone: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Communications - Telefax: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Communications - Radio: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Communications - Radiotelephone: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Communications - Airport: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Communications - Rail: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Search and Rescue: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature NAVAREA: 21
# The number of values for feature Facilities - Wharves: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Facilities - Anchorage: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Facilities - Dangerous Cargo Anchorage: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Facilities - Med Mooring: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Facilities - Beach Mooring: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Facilities - Ice Mooring: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Facilities - Ro-Ro: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Facilities - Solid Bulk: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Facilities - Liquid Bulk: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Facilities - Container: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Facilities - Breakbulk: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Facilities - Oil Terminal: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Facilities - LNG Terminal: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Facilities - Other: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Medical Facilities: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Garbage Disposal: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Chemical Holding Tank Disposal: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Degaussing: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Dirty Ballast Disposal: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Cranes - Fixed: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Cranes - Mobile: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Cranes - Floating: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Cranes Container: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Lifts - 100+ Tons: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Lifts - 50-100 Tons: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Lifts - 25-49 Tons: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Lifts - 0-24 Tons: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Services - Longshoremen: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Services - Electricity: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Services -Steam: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Services - Navigation Equipment: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Services - Electrical Repair: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Services - Ice Breaking: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Services -Diving: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Supplies - Provisions: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Supplies - Potable Water: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Supplies - Fuel Oil: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Supplies - Diesel Oil: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Supplies - Aviation Fuel: 2 -- ['No' 'Unknown']
# The number of values for feature Supplies - Deck: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Supplies - Engine: 3 -- ['No' 'Unknown' 'Yes']
# The number of values for feature Repairs: 6 -- ['Emergency Only' 'Limited' 'Major' 'Moderate' 'None' 'Unknown']
# The number of values for feature Dry Dock: 5 -- ['Large' 'Medium' 'None' 'Small' 'Unknown']
# The number of values for feature Railway: 5 -- ['Large' 'Medium' 'None' 'Small' 'Unknown']
# The number of values for feature Latitude: 2692
# The number of values for feature Longitude: 3207
#
# Null value counts:
# ﻿OID_                      0
# World Port Index Number    0
# Region Name                0
# Main Port Name             0
# Alternate Port Name        0
#                           ..
# Repairs                    0
# Dry Dock                   0
# Railway                    0
# Latitude                   0
# Longitude                  0
# Length: 109, dtype: int64
# Processing completed successfully!
